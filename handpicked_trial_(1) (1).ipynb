# %%
#volume and mean crossovers condition

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import pandas_datareader.data as web

# Download the list of S&P 500 stocks
sp500 = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
stocks = sp500.Symbol.to_list()

start_date = "2017-01-01"
end_date = "2023-01-31"

primary_stocks = []
secondary_stocks = []

for stock in stocks:
    try:
        # Get the stock price data from Yahoo Finance
        stock_data = yf.download(stock, start=start_date, end=end_date)

        # Calculate the 1-year moving average
        moving_avg = stock_data["Close"].rolling(window=252).mean()

        # Calculate the crossovers
        crossover = np.where(stock_data["Close"] > moving_avg, 1, -1)
        crossover = np.sign(np.diff(crossover))

        # Count the number of positive and negative crossovers
        num_positive_crossovers = len(np.where(crossover > 0)[0])
        num_negative_crossovers = len(np.where(crossover < 0)[0])

        # Determine the trend if the average volume is greater than 1000000
        if stock_data["Volume"].mean() > 1000000:
            if num_positive_crossovers > num_negative_crossovers:
                primary_stocks.append(stock)
            else:
                secondary_stocks.append(stock)
        else:
            secondary_stocks.append(stock)
    except Exception:
        pass

print("Primary stocks:")
print(primary_stocks)

print("Secondary stocks:")
print(secondary_stocks)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Primary stocks:
# ['AES', 'AFL', 'A', 'APD', 'ALK', 'ALB', 'AAL', 'AXP', 'AIG', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'AON', 'APA', 'AMAT', 'APTV', 'ACGL', 'ANET', 'T', 'ADSK', 'BKR', 'BBWI', 'BDX', 'WRB', 'BBY', 'BIIB', 'BK', 'BA', 'BWA', 'BSX', 'AVGO', 'CDNS', 'CPB', 'COF', 'CAH', 'CARR', 'CAT', 'CBRE', 'CDAY', 'SCHW', 'CVX', 'CB', 'CI', 'CSCO', 'C', 'CFG', 'CAG', 'COP', 'ED', 'CEG', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'CMI', 'DHI', 'DRI', 'DE', 'DAL', 'DXCM', 'FANG', 'DFS', 'DOV', 'DOW', 'DD', 'ETN', 'EBAY', 'EIX', 'EA', 'ELV', 'LLY', 'EMR', 'EOG', 'EFX', 'EL', 'ETSY', 'EXPD', 'XOM', 'FSLR', 'FE', 'FISV', 'FMC', 'FTV', 'BEN', 'FCX', 'GE', 'GIS', 'GILD', 'GS', 'HAL', 'HIG', 'HCA', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HST', 'HWM', 'HUM', 'HBAN', 'IBM', 'ITW', 'INCY', 'IR', 'IPG', 'IQV', 'IRM', 'JCI', 'JPM', 'JNPR', 'KEYS', 'KIM', 'KLAC', 'KHC', 'LRCX', 'LW', 'LVS', 'LEN', 'LIN', 'LKQ', 'LMT', 'L', 'LOW', 'LYB', 'MRO', 'MPC', 'MAR', 'MMC', 'MA', 'MCD', 'MCK', 'MRK', 'MET', 'MGM', 'MCHP', 'MRNA', 'MDLZ', 'MNST', 'MS', 'NDAQ', 'NFLX', 'NWSA', 'NKE', 'NUE', 'NVDA', 'NXPI', 'OXY', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PNR', 'PCG', 'PM', 'PSX', 'PPG', 'PPL', 'PFG', 'PGR', 'PHM', 'QRVO', 'PWR', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'RF', 'ROST', 'RCL', 'SPGI', 'SLB', 'SRE', 'SPG', 'SWKS', 'SBUX', 'STT', 'STLD', 'SYK', 'SYF', 'SNPS', 'TMUS', 'TPR', 'TRGP', 'TEL', 'TER', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TRV', 'USB', 'UAL', 'URI', 'VLO', 'VTR', 'VRTX', 'VTRS', 'VICI', 'V', 'VMC', 'WAB', 'WMT', 'WFC', 'WYNN', 'XYL', 'YUM', 'ZBH']
# Secondary stocks:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AKAM', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AMD', 'AEE', 'AEP', 'AMT', 'AWK', 'AMP', 'ANSS', 'AAPL', 'AJG', 'AIZ', 'ATO', 'AZO', 'AVB', 'AVY', 'AXON', 'BALL', 'BAC', 'BAX', 'BRK.B', 'BIO', 'TECH', 'BLK', 'BKNG', 'BXP', 'BMY', 'BR', 'BRO', 'BF.B', 'BG', 'CHRW', 'CZR', 'CPT', 'KMX', 'CCL', 'CTLT', 'CBOE', 'CDW', 'CE', 'CNC', 'CNP', 'CF', 'CRL', 'CHTR', 'CMG', 'CHD', 'CINF', 'CTAS', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'STZ', 'COO', 'COST', 'CTRA', 'CCI', 'CSX', 'CVS', 'DHR', 'DVA', 'XRAY', 'DVN', 'DLR', 'DISH', 'DIS', 'DG', 'DLTR', 'D', 'DPZ', 'DTE', 'DUK', 'DXC', 'EMN', 'ECL', 'EW', 'ENPH', 'ETR', 'EPAM', 'EQT', 'EQIX', 'EQR', 'ESS', 'RE', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXR', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FITB', 'FIS', 'FLT', 'F', 'FTNT', 'FOXA', 'FOX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GM', 'GPC', 'GL', 'GPN', 'HAS', 'PEAK', 'HRL', 'HPQ', 'HII', 'IEX', 'IDXX', 'ILMN', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'INTU', 'ISRG', 'IVZ', 'INVH', 'JBHT', 'JKHY', 'J', 'JNJ', 'K', 'KDP', 'KEY', 'KMB', 'KMI', 'KR', 'LHX', 'LH', 'LDOS', 'LNC', 'LYV', 'MTB', 'MKTX', 'MLM', 'MAS', 'MTCH', 'MKC', 'MDT', 'META', 'MTD', 'MU', 'MSFT', 'MAA', 'MHK', 'MOH', 'TAP', 'MPWR', 'MCO', 'MOS', 'MSI', 'MSCI', 'NTAP', 'NWL', 'NEM', 'NWS', 'NEE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NVR', 'ORLY', 'ODFL', 'OGN', 'PKG', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PEP', 'PFE', 'PNW', 'PXD', 'PNC', 'POOL', 'PG', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'QCOM', 'REGN', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'CRM', 'SBAC', 'STX', 'SEE', 'NOW', 'SHW', 'SJM', 'SNA', 'SEDG', 'SO', 'LUV', 'SWK', 'STE', 'SYY', 'TROW', 'TTWO', 'TGT', 'TDY', 'TFX', 'TSLA', 'TDG', 'TRMB', 'TFC', 'TYL', 'TSN', 'UDR', 'ULTA', 'UNP', 'UPS', 'UNH', 'UHS', 'VRSN', 'VRSK', 'VZ', 'VFC', 'WBA', 'WBD', 'WM', 'WAT', 'WEC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'XEL', 'ZBRA', 'ZION', 'ZTS']

# %%
primary_stocks
# Out:
# ['AES',
#  'AFL',
#  'A',
#  'APD',
#  'ALK',
#  'ALB',
#  'AAL',
#  'AXP',
#  'AIG',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'AON',
#  'APA',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ANET',
#  'T',
#  'ADSK',
#  'BKR',
#  'BBWI',
#  'BDX',
#  'WRB',
#  'BBY',
#  'BIIB',
#  'BK',
#  'BA',
#  'BWA',
#  'BSX',
#  'AVGO',
#  'CDNS',
#  'CPB',
#  'COF',
#  'CAH',
#  'CARR',
#  'CAT',
#  'CBRE',
#  'CDAY',
#  'SCHW',
#  'CVX',
#  'CB',
#  'CI',
#  'CSCO',
#  'C',
#  'CFG',
#  'CAG',
#  'COP',
#  'ED',
#  'CEG',
#  'CPRT',
#  'GLW',
#  'CTVA',
#  'CSGP',
#  'CMI',
#  'DHI',
#  'DRI',
#  'DE',
#  'DAL',
#  'DXCM',
#  'FANG',
#  'DFS',
#  'DOV',
#  'DOW',
#  'DD',
#  'ETN',
#  'EBAY',
#  'EIX',
#  'EA',
#  'ELV',
#  'LLY',
#  'EMR',
#  'EOG',
#  'EFX',
#  'EL',
#  'ETSY',
#  'EXPD',
#  'XOM',
#  'FSLR',
#  'FE',
#  'FISV',
#  'FMC',
#  'FTV',
#  'BEN',
#  'FCX',
#  'GE',
#  'GIS',
#  'GILD',
#  'GS',
#  'HAL',
#  'HIG',
#  'HCA',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HST',
#  'HWM',
#  'HUM',
#  'HBAN',
#  'IBM',
#  'ITW',
#  'INCY',
#  'IR',
#  'IPG',
#  'IQV',
#  'IRM',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'KEYS',
#  'KIM',
#  'KLAC',
#  'KHC',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LEN',
#  'LIN',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LYB',
#  'MRO',
#  'MPC',
#  'MAR',
#  'MMC',
#  'MA',
#  'MCD',
#  'MCK',
#  'MRK',
#  'MET',
#  'MGM',
#  'MCHP',
#  'MRNA',
#  'MDLZ',
#  'MNST',
#  'MS',
#  'NDAQ',
#  'NFLX',
#  'NWSA',
#  'NKE',
#  'NUE',
#  'NVDA',
#  'NXPI',
#  'OXY',
#  'OMC',
#  'ON',
#  'OKE',
#  'ORCL',
#  'OTIS',
#  'PCAR',
#  'PNR',
#  'PCG',
#  'PM',
#  'PSX',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PGR',
#  'PHM',
#  'QRVO',
#  'PWR',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'RF',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'SLB',
#  'SRE',
#  'SPG',
#  'SWKS',
#  'SBUX',
#  'STT',
#  'STLD',
#  'SYK',
#  'SYF',
#  'SNPS',
#  'TMUS',
#  'TPR',
#  'TRGP',
#  'TEL',
#  'TER',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TRV',
#  'USB',
#  'UAL',
#  'URI',
#  'VLO',
#  'VTR',
#  'VRTX',
#  'VTRS',
#  'VICI',
#  'V',
#  'VMC',
#  'WAB',
#  'WMT',
#  'WFC',
#  'WYNN',
#  'XYL',
#  'YUM',
#  'ZBH']

# %%
#sharpe ratio condition

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from tabulate import tabulate

def std_dev(stocks, start_date, end_date):
    data = yf.download(stocks, start=start_date, end=end_date)['Adj Close']
    ret = data.pct_change()
    
    # Select only the desired stocks
    ret = ret[stocks]
    
    # Calculate the standard deviation of daily percentage changes
    std = ret.std() * np.sqrt(252)
    results = pd.DataFrame({'Standard Deviation (%)': round(std * 100, 4)})
    results.index.name = 'Stock'
    return results.sort_values('Standard Deviation (%)', ascending=False)

# Define the start and end dates for the analysis
start_date = '2017-01-01'
end_date = '2022-12-31'

# Call the std_dev function for the primary_stocks list and sort the results by standard deviation
results = std_dev(primary_stocks, start_date, end_date).sort_values('Standard Deviation (%)', ascending=False)

# Split the sorted results into 9 equal sublists based on standard deviation and name the stock lists
n = 7
chunk_size = len(results) // n
stocks_lists = [results.iloc[i:i+chunk_size].index.tolist() for i in range(0, len(results), chunk_size)]
for i, stocks in enumerate(stocks_lists):
    globals()['stock_list_'+str(i+1)] = stocks

# Call the std_dev function for each sublist of stocks and print the results with stock list names
for i, stocks in enumerate(stocks_lists):
    print(f'Stocks List {i+1}: {globals()["stock_list_"+str(i+1)]}')
    results = std_dev(stocks, start_date, end_date)
    print(tabulate(results, headers='keys', tablefmt='psql'))
    print()
# Out:
# [*********************100%***********************]  219 of 219 completed
# Stocks List 1: ['MRNA', 'PCG', 'APA', 'ETSY', 'RCL', 'BBWI', 'OXY', 'AAL', 'FANG', 'MRO', 'TRGP', 'UAL', 'WYNN', 'HAL', 'ON', 'FCX', 'MGM', 'DXCM', 'NVDA', 'TPR', 'HES', 'CDAY', 'BIIB', 'CEG', 'FSLR', 'BA', 'LRCX', 'SLB', 'OKE', 'NFLX', 'EOG']
# [*********************100%***********************]  31 of 31 completed
# +---------+--------------------------+
# | Stock   |   Standard Deviation (%) |
# |---------+--------------------------|
# | MRNA    |                  80.2285 |
# | PCG     |                  74.4111 |
# | APA     |                  66.5825 |
# | ETSY    |                  60.9577 |
# | RCL     |                  60.2841 |
# | BBWI    |                  59.3656 |
# | OXY     |                  58.0704 |
# | AAL     |                  57.6486 |
# | FANG    |                  57.1677 |
# | MRO     |                  56.7675 |
# | TRGP    |                  56.4011 |
# | UAL     |                  54.95   |
# | WYNN    |                  53.2232 |
# | HAL     |                  51.8179 |
# | ON      |                  51.7192 |
# | FCX     |                  51.5754 |
# | MGM     |                  51.0934 |
# | DXCM    |                  50.5295 |
# | NVDA    |                  50.1331 |
# | TPR     |                  48.7563 |
# | HES     |                  48.4606 |
# | CDAY    |                  48.2497 |
# | BIIB    |                  47.8278 |
# | CEG     |                  47.4625 |
# | FSLR    |                  47.3062 |
# | BA      |                  47.0245 |
# | LRCX    |                  45.5919 |
# | SLB     |                  45.3059 |
# | OKE     |                  45.2821 |
# | NFLX    |                  45.07   |
# | EOG     |                  45.0009 |
# +---------+--------------------------+
#
# Stocks List 2: ['ALK', 'DAL', 'ALB', 'VLO', 'HWM', 'MPC', 'SPG', 'URI', 'AMAT', 'APTV', 'BKR', 'ANET', 'DFS', 'CARR', 'TER', 'SYF', 'KLAC', 'LVS', 'DRI', 'QRVO', 'COP', 'STLD', 'RL', 'DOW', 'MCHP', 'CFG', 'NXPI', 'LEN', 'VTR', 'GE', 'COF']
# [*********************100%***********************]  31 of 31 completed
# +---------+--------------------------+
# | Stock   |   Standard Deviation (%) |
# |---------+--------------------------|
# | ALK     |                  44.4395 |
# | DAL     |                  44.4386 |
# | ALB     |                  44.4059 |
# | VLO     |                  44.3999 |
# | HWM     |                  44.3607 |
# | MPC     |                  44.2992 |
# | SPG     |                  44.036  |
# | URI     |                  43.9755 |
# | AMAT    |                  43.8926 |
# | APTV    |                  43.5312 |
# | BKR     |                  43.4358 |
# | ANET    |                  43.2966 |
# | DFS     |                  43.261  |
# | CARR    |                  43.164  |
# | TER     |                  42.8381 |
# | SYF     |                  42.4577 |
# | KLAC    |                  42.08   |
# | LVS     |                  42.061  |
# | DRI     |                  42.0516 |
# | QRVO    |                  42.0193 |
# | COP     |                  42.0078 |
# | STLD    |                  41.9523 |
# | RL      |                  41.5119 |
# | DOW     |                  41.2434 |
# | MCHP    |                  41.1244 |
# | CFG     |                  40.9968 |
# | NXPI    |                  40.908  |
# | LEN     |                  40.8026 |
# | VTR     |                  40.7362 |
# | GE      |                  40.6899 |
# | COF     |                  40.0207 |
# +---------+--------------------------+
#
# Stocks List 3: ['ADSK', 'VTRS', 'SWKS', 'KIM', 'BBY', 'PHM', 'RF', 'PSX', 'LYB', 'HST', 'DHI', 'NUE', 'CTVA', 'AIG', 'MAR', 'TXT', 'IR', 'LKQ', 'HBAN', 'HCA', 'ROST', 'STT', 'C', 'INCY', 'PFG', 'AVGO', 'BWA', 'WAB', 'HPE', 'REG', 'WFC']
# [*********************100%***********************]  31 of 31 completed
# +---------+--------------------------+
# | Stock   |   Standard Deviation (%) |
# |---------+--------------------------|
# | ADSK    |                  39.7207 |
# | VTRS    |                  39.6702 |
# | SWKS    |                  39.6135 |
# | KIM     |                  39.5771 |
# | BBY     |                  39.5714 |
# | PHM     |                  39.4478 |
# | RF      |                  39.1103 |
# | PSX     |                  38.8114 |
# | LYB     |                  38.5722 |
# | HST     |                  38.2314 |
# | DHI     |                  37.8004 |
# | NUE     |                  37.5693 |
# | CTVA    |                  37.5194 |
# | AIG     |                  37.3574 |
# | MAR     |                  37.1863 |
# | TXT     |                  37.1703 |
# | IR      |                  37.0096 |
# | LKQ     |                  36.8184 |
# | HBAN    |                  36.4719 |
# | HCA     |                  36.4653 |
# | ROST    |                  36.4088 |
# | STT     |                  36.3026 |
# | C       |                  36.0781 |
# | INCY    |                  35.8457 |
# | PFG     |                  35.7903 |
# | AVGO    |                  35.4386 |
# | BWA     |                  35.4205 |
# | WAB     |                  35.3114 |
# | HPE     |                  35.1934 |
# | REG     |                  35.1101 |
# | WFC     |                  34.9108 |
# +---------+--------------------------+
#
# Stocks List 4: ['VICI', 'CBRE', 'BEN', 'SCHW', 'IPG', 'AXP', 'VRTX', 'AES', 'CDNS', 'DD', 'MS', 'RJF', 'PWR', 'HIG', 'VMC', 'ADI', 'CVX', 'CSGP', 'LW', 'MET', 'FMC', 'LOW', 'HLT', 'NWSA', 'GLW', 'DE', 'CAH', 'CI', 'ELV', 'KEYS', 'NKE']
# [*********************100%***********************]  31 of 31 completed
# +---------+--------------------------+
# | Stock   |   Standard Deviation (%) |
# |---------+--------------------------|
# | VICI    |                  34.8883 |
# | CBRE    |                  34.8585 |
# | BEN     |                  34.7846 |
# | SCHW    |                  34.711  |
# | IPG     |                  34.6858 |
# | AXP     |                  34.6824 |
# | VRTX    |                  34.5865 |
# | AES     |                  34.192  |
# | CDNS    |                  34.0794 |
# | DD      |                  33.662  |
# | MS      |                  33.5493 |
# | RJF     |                  33.5466 |
# | PWR     |                  33.4255 |
# | HIG     |                  33.3772 |
# | VMC     |                  33.3684 |
# | ADI     |                  33.1286 |
# | CVX     |                  33.0232 |
# | CSGP    |                  32.9975 |
# | LW      |                  32.8799 |
# | MET     |                  32.5868 |
# | FMC     |                  32.4193 |
# | LOW     |                  32.2984 |
# | HLT     |                  32.2399 |
# | NWSA    |                  32.1351 |
# | GLW     |                  32.1334 |
# | DE      |                  32.0357 |
# | CAH     |                  31.9993 |
# | CI      |                  31.8906 |
# | ELV     |                  31.8446 |
# | KEYS    |                  31.7719 |
# | NKE     |                  31.7654 |
# +---------+--------------------------+
#
# Stocks List 5: ['SNPS', 'EFX', 'CAT', 'EL', 'EBAY', 'XOM', 'GS', 'IQV', 'HUM', 'USB', 'MA', 'RTX', 'EA', 'IRM', 'TJX', 'PNR', 'TXN', 'TSCO', 'EMR', 'ACGL', 'KHC', 'ZBH', 'CPRT', 'JPM', 'EIX', 'OTIS', 'OMC', 'L', 'XYL', 'BK', 'MCK']
# [*********************100%***********************]  31 of 31 completed
# +---------+--------------------------+
# | Stock   |   Standard Deviation (%) |
# |---------+--------------------------|
# | SNPS    |                  31.7227 |
# | EFX     |                  31.6218 |
# | CAT     |                  31.6049 |
# | EL      |                  31.3256 |
# | EBAY    |                  31.2741 |
# | XOM     |                  31.2416 |
# | GS      |                  31.2406 |
# | IQV     |                  31.0958 |
# | HUM     |                  31.0837 |
# | USB     |                  31.0541 |
# | MA      |                  30.8531 |
# | RTX     |                  30.5962 |
# | EA      |                  30.5705 |
# | IRM     |                  30.4581 |
# | TJX     |                  30.4319 |
# | PNR     |                  30.3565 |
# | TXN     |                  30.3032 |
# | TSCO    |                  30.2799 |
# | EMR     |                  30.2161 |
# | ACGL    |                  30.2094 |
# | KHC     |                  30.1738 |
# | ZBH     |                  30.1237 |
# | CPRT    |                  30.0438 |
# | JPM     |                  30.0283 |
# | EIX     |                  29.9829 |
# | OTIS    |                  29.8217 |
# | OMC     |                  29.7868 |
# | L       |                  29.7218 |
# | XYL     |                  29.7083 |
# | BK      |                  29.7069 |
# | MCK     |                  29.6158 |
# +---------+--------------------------+
#
# Stocks List 6: ['TEL', 'ETN', 'ABC', 'O', 'AFL', 'SBUX', 'HOLX', 'SYK', 'HSIC', 'BSX', 'PPG', 'FISV', 'ORCL', 'JCI', 'DOV', 'CMI', 'LLY', 'SPGI', 'TT', 'FTV', 'TMUS', 'MNST', 'FE', 'CAG', 'A', 'JNPR', 'CSCO', 'V', 'TMO', 'HD', 'CB']
# [*********************100%***********************]  31 of 31 completed
# +---------+--------------------------+
# | Stock   |   Standard Deviation (%) |
# |---------+--------------------------|
# | TEL     |                  29.5682 |
# | ETN     |                  29.3918 |
# | ABC     |                  29.2911 |
# | O       |                  29.2652 |
# | AFL     |                  29.1776 |
# | SBUX    |                  29.0883 |
# | HOLX    |                  29.0243 |
# | SYK     |                  28.9277 |
# | HSIC    |                  28.7683 |
# | BSX     |                  28.7545 |
# | PPG     |                  28.6612 |
# | FISV    |                  28.4902 |
# | ORCL    |                  28.2576 |
# | JCI     |                  28.1364 |
# | DOV     |                  28.0672 |
# | CMI     |                  28.06   |
# | LLY     |                  28.0278 |
# | SPGI    |                  28.005  |
# | TT      |                  27.998  |
# | FTV     |                  27.9306 |
# | TMUS    |                  27.9175 |
# | MNST    |                  27.9007 |
# | FE      |                  27.8766 |
# | CAG     |                  27.8578 |
# | A       |                  27.728  |
# | JNPR    |                  27.7019 |
# | CSCO    |                  27.4624 |
# | V       |                  27.3663 |
# | TMO     |                  26.7906 |
# | HD      |                  26.7795 |
# | CB      |                  26.5039 |
# +---------+--------------------------+
#
# Stocks List 7: ['TRV', 'WRB', 'CPB', 'AME', 'PCAR', 'APD', 'ITW', 'SRE', 'GILD', 'IBM', 'PM', 'APH', 'DGX', 'LIN', 'PPL', 'EXPD', 'NDAQ', 'HON', 'LMT', 'AON', 'PGR', 'YUM', 'AMGN', 'T', 'BDX', 'GIS', 'WMT', 'ED', 'MCD', 'MMC', 'MRK']
# [*********************100%***********************]  31 of 31 completed
# +---------+--------------------------+
# | Stock   |   Standard Deviation (%) |
# |---------+--------------------------|
# | TRV     |                  26.4083 |
# | WRB     |                  26.4033 |
# | CPB     |                  26.3705 |
# | AME     |                  26.3085 |
# | PCAR    |                  26.291  |
# | APD     |                  26.2383 |
# | ITW     |                  26.2026 |
# | SRE     |                  26.2019 |
# | GILD    |                  26.0074 |
# | IBM     |                  25.9427 |
# | PM      |                  25.876  |
# | APH     |                  25.8657 |
# | DGX     |                  25.6577 |
# | LIN     |                  25.601  |
# | PPL     |                  25.5077 |
# | EXPD    |                  25.4013 |
# | NDAQ    |                  25.3322 |
# | HON     |                  25.2104 |
# | LMT     |                  25.0245 |
# | AON     |                  24.9402 |
# | PGR     |                  24.8601 |
# | YUM     |                  24.7329 |
# | AMGN    |                  24.6436 |
# | T       |                  24.3389 |
# | BDX     |                  23.8204 |
# | GIS     |                  22.9706 |
# | WMT     |                  22.72   |
# | ED      |                  22.709  |
# | MCD     |                  22.5699 |
# | MMC     |                  22.4257 |
# | MRK     |                  22.1595 |
# +---------+--------------------------+
#
# Stocks List 8: ['HSY', 'MDLZ']
# [*********************100%***********************]  2 of 2 completed
# +---------+--------------------------+
# | Stock   |   Standard Deviation (%) |
# |---------+--------------------------|
# | HSY     |                  22.0304 |
# | MDLZ    |                  21.2352 |
# +---------+--------------------------+

# %%
stock_list_1
# Out:
# ['MRNA',
#  'PCG',
#  'APA',
#  'ETSY',
#  'RCL',
#  'BBWI',
#  'OXY',
#  'AAL',
#  'FANG',
#  'MRO',
#  'TRGP',
#  'UAL',
#  'WYNN',
#  'HAL',
#  'ON',
#  'FCX',
#  'MGM',
#  'DXCM',
#  'NVDA',
#  'TPR',
#  'HES',
#  'CDAY',
#  'BIIB',
#  'CEG',
#  'FSLR',
#  'BA',
#  'LRCX',
#  'SLB',
#  'OKE',
#  'NFLX',
#  'EOG']

# %%
import pandas as pd
import yfinance as yf

def moving_avg(stock_list, nDays):
    # Define the start and end dates for the analysis
    start_date = '2022-01-01'
    end_date = '2022-12-31'

    # Download the historical data for the selected stocks
    data = yf.download(stock_list, start=start_date, end=end_date)['Adj Close']

    # Calculate the moving averages for each stock
    moving_avgs = data.rolling(window=20).mean().tail(1).transpose()
    moving_avgs = pd.concat([moving_avgs, data.rolling(window=50).mean().tail(1).transpose()], axis=1)
    moving_avgs = pd.concat([moving_avgs, data.rolling(window=200).mean().tail(1).transpose()], axis=1)

    # Rename the columns
    moving_avgs.columns = ['20-day MA', '50-day MA', '200-day MA']

    # Get the current price of each stock based on the 'Adj Close' column
    current_prices = data.tail(1).transpose()
    current_prices.columns = ['Close']

    # Create empty lists to store the stocks that are greater than the respective moving averages
    new_20_list = []
    new_50_list = []
    new_200_list = []

    # Iterate over each stock
    for stock in stock_list:
        # Check if the current price is greater than the 20-day moving average
        if current_prices.loc[stock, 'Close'] > moving_avgs.loc[stock, '20-day MA']:
            new_20_list.append(stock)

        # Check if the current price is greater than the 50-day moving average
        if current_prices.loc[stock, 'Close'] > moving_avgs.loc[stock, '50-day MA']:
            new_50_list.append(stock)

        # Check if the current price is greater than the 200-day moving average
        if current_prices.loc[stock, 'Close'] > moving_avgs.loc[stock, '200-day MA']:
            new_200_list.append(stock)

    # Return the stocks that are greater than the respective moving averages
    return new_20_list, new_50_list, new_200_list

# %%
new_moving_average = moving_avg(stock_list_7, 20)
new_20_list = new_moving_average[0]
print(new_20_list)

new_50_list = new_moving_average[1]
print(new_50_list)

new_200_list = new_moving_average[2]
print(new_200_list)
# Out:
# [*********************100%***********************]  31 of 31 completed
# ['TRV', 'CPB', 'PM', 'DGX', 'HON', 'LMT', 'PGR', 'BDX', 'MRK']
# ['TRV', 'CPB', 'AME', 'PCAR', 'APD', 'ITW', 'GILD', 'PM', 'DGX', 'LIN', 'PPL', 'HON', 'LMT', 'AON', 'PGR', 'YUM', 'BDX', 'GIS', 'ED', 'MRK']
# ['TRV', 'WRB', 'CPB', 'AME', 'PCAR', 'APD', 'ITW', 'GILD', 'IBM', 'PM', 'APH', 'DGX', 'LIN', 'PPL', 'EXPD', 'NDAQ', 'HON', 'LMT', 'AON', 'PGR', 'YUM', 'AMGN', 'T', 'BDX', 'GIS', 'WMT', 'ED', 'MCD', 'MMC', 'MRK']

# %%
import pandas as pd
import yfinance as yf

# Define the start and end dates for the analysis
start_date = '2017-01-01'
end_date = '2022-12-31'

# Define the risk-free rate
rf_rate = 0.02

def calculate_alphas(moving_avg_list):
    # Download the historical data for the selected stock list
    data = yf.download(moving_avg_list, start=start_date, end=end_date)['Adj Close']

    # Calculate the daily returns for each stock
    returns = data.pct_change().dropna()

    # Download the historical data for the market index (e.g., S&P 500)
    market = yf.download('^GSPC', start=start_date, end=end_date)['Adj Close']
    market_returns = market.pct_change().dropna()

    # Calculate the beta and alpha for each stock
    alphas = {}
    for stock in returns.columns:
        cov = returns[stock].cov(market_returns)
        var = market_returns.var()
        beta = cov / var
        rf_adjusted = (1 + rf_rate) ** (1/365) - 1
        alpha = returns[stock].mean() - rf_adjusted - beta * (market_returns.mean() - rf_adjusted)
        alphas[stock] = alpha

    # Sort the stocks by alpha in descending order
    results = pd.Series(alphas).sort_values(ascending=False)

    # Print the results
    print("Stocks sorted by alpha for " + str(moving_avg_list) + ":")
    print(results)

# %%
calculate_alphas(new_200_list)
# Out:
# [*********************100%***********************]  30 of 30 completed
# [*********************100%***********************]  1 of 1 completed
# Stocks sorted by alpha for ['TRV', 'WRB', 'CPB', 'AME', 'PCAR', 'APD', 'ITW', 'GILD', 'IBM', 'PM', 'APH', 'DGX', 'LIN', 'PPL', 'EXPD', 'NDAQ', 'HON', 'LMT', 'AON', 'PGR', 'YUM', 'AMGN', 'T', 'BDX', 'GIS', 'WMT', 'ED', 'MCD', 'MMC', 'MRK']:
# PGR     0.000784
# LIN     0.000468
# AON     0.000462
# NDAQ    0.000461
# WRB     0.000432
# WMT     0.000412
# AME     0.000399
# MCD     0.000393
# MRK     0.000393
# MMC     0.000390
# LMT     0.000351
# APD     0.000331
# YUM     0.000305
# AMGN    0.000284
# EXPD    0.000258
# DGX     0.000255
# APH     0.000255
# GIS     0.000252
# HON     0.000219
# ITW     0.000189
# BDX     0.000185
# ED      0.000182
# PCAR    0.000178
# TRV     0.000158
# GILD    0.000109
# PM      0.000103
# CPB     0.000049
# PPL    -0.000104
# IBM    -0.000138
# T      -0.000254
# dtype: float64

# %%
#scenario risk 1

# %%
#60%- group 1, 20% - group 3, 20% - group 5 - risk level (regardless of moving average)
#current list, current list + 2 list, current list + 4 list.

# %%
current_list = stock_list_1
list_2 = stock_list_3
list_4 = stock_list_5

# %%
def invest(amount_invested, risk_level, current_list, list_2, list_4, investment_timeframe):
    # Determine the amount to invest in each stock list
    current_list_investment = 0.6 * amount_invested
    list2_investment = 0.2 * amount_invested
    list4_investment = 0.2 * amount_invested

    # Calculate the moving averages for each stock list
    #current_list_20, current_list_50, current_list_200 = moving_avg(current_list)
    #list2_20, list2_50, list2_200 = moving_avg(list_2)
    #list4_20, list4_50, list4_200 = moving_avg(list_4)

    if investment_timeframe == '20_days':
        current_list_stocks = moving_avg(current_list, 20)
        list2_stocks = moving_avg(list_2, 20)
        list4_stocks = moving_avg(list_4, 20)
    elif investment_timeframe == '50_days':
        current_list_stocks = moving_avg(current_list, 50)
        list2_stocks = moving_avg(list_2, 50)
        list4_stocks = moving_avg(list_4, 50)
    else:
        current_list_stocks = moving_avg(current_list, 200)
        list2_stocks = moving_avg(list_2, 200)
        list4_stocks = moving_avg(list_4, 200)

    # Calculate the alphas for each stock list
    current_list_alphas = calculate_alphas(current_list_stocks)
    list2_alphas = calculate_alphas(list2_stocks)
    list4_alphas = calculate_alphas(list4_stocks)

    # Select the top stocks from each list based on alpha values
    current_list_top_stocks = current_list_alphas.index[:4].tolist()
    list2_top_stocks = list2_alphas.index[:2].tolist()
    list4_top_stocks = list4_alphas.index[:2].tolist()

    # Invest in the top stocks
    current_list_investment_per_stock = current_list_investment / 4
    for stock in current_list_top_stocks:
        current_price = yf.Ticker(stock[0]).info['regularMarketPrice']
        num_shares = round(current_list_investment_per_stock / current_price, 1)
        print(f"Buy {num_shares} shares of {stock[0]} at {current_price} per share")

    list2_investment_per_stock = list2_investment / 2
    for stock in list2_top_stocks:
        current_price = yf.Ticker(stock[0]).info['regularMarketPrice']
        num_shares = round(list2_investment_per_stock / current_price, 1)
        print(f"Buy {num_shares} shares of {stock[0]} at {current_price} per share")

    list4_investment_per_stock = list4_investment / 2
    for stock in list4_top_stocks:
        current_price = yf.Ticker(stock[0]).info['regularMarketPrice']
        num_shares = round(list4_investment_per_stock / current_price, 1)
        print(f"Buy {num_shares} shares of {stock[0]} at {current_price} per share")


#after this what I need to figure out is some of th arguments and some of the linkages

# %%
invest(3000,1,current_list, list_2, list_4, 20_days)
# Out:
#   File "<ipython-input-9-8002c4bbc9ec>", line 1
#     invest(3000,1,current_list, list_2, list_4, 20_days)
#                                                   ^
# SyntaxError: invalid decimal literal
